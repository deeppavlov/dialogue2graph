# %%
# !poetry install
# Out:
# Installing dependencies from lock file
#
# No dependencies to install or update
#
# Installing the current project: dialogue2graph (0.1.0)Installing the current project: dialogue2graph (0.1.0)

# %% [markdown]
# # Data generation
#
# In this example we use `LoopedGraphGenerator` to create a pair Graph-Dialogues as a synthetic data

# %%
import os
import json
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI
from dialogue2graph.datasets.complex_dialogues.generation import LoopedGraphGenerator
from dialogue2graph import Dialogue, Graph

load_dotenv()
# Out:
# /home/askatasuna/.cache/pypoetry/virtualenvs/dialogue2graph-VcuUrJCU-py3.11/lib/python3.11/site-packages/pydantic/_internal/_fields.py:192: UserWarning: Field name "validate" in "Dialogue" shadows an attribute in parent "BaseModel"
#   warnings.warn(
# True

# %%
gen_model = ChatOpenAI(model='openai/gpt-4o')
val_model = ChatOpenAI(model='openai/gpt-4o-mini')

# %%
gen = LoopedGraphGenerator(
    generation_model=gen_model,
    validation_model=val_model,
)
# Out:
# WARNING:dialogue2graph.utils.prompt_caching:Error setting up cache: No module named 'psycopg2'. Falling back to in-memory cache
# INFO:dialogue2graph.utils.prompt_caching:Using in-memory cache
# WARNING:dialogue2graph.utils.prompt_caching:Error setting up cache: No module named 'psycopg2'. Falling back to in-memory cache
# INFO:dialogue2graph.utils.prompt_caching:Using in-memory cache

# %%
gen.invoke(topic='antivirus software problems', seed=30)
# Out:
# INFO:dialogue2graph.datasets.complex_dialogues.generation:
# ...
# INFO:dialogue2graph.datasets.complex_dialogues.generation:Generating graph for topic: antivirus software problems
# INFO:dialogue2graph.datasets.complex_dialogues.generation:==================================================
# INFO:dialogue2graph.datasets.complex_dialogues.generation:Generating Graph ...
# WARNING:dialogue2graph.utils.prompt_caching:Error setting up cache: No module named 'psycopg2'. Falling back to in-memory cache
# INFO:dialogue2graph.utils.prompt_caching:Using in-memory cache
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 gen.invoke(topic='antivirus software problems', seed=30)
#
# File ~/Документы/DeepPavlov/chatsky-llm-autoconfig/dialogue2graph/datasets/complex_dialogues/generation.py:272, in LoopedGraphGenerator.invoke(self, topic, seed)
#     270 try:
# ...
